# %% [markdown]
# <a href="https://colab.research.google.com/github/P-muriuki/Financial-Inclusion/blob/main/Draft_Financial_Inclusion_Zindi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
from google.colab import drive
import seaborn as sns

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
url = '/content/drive/MyDrive/Colab Notebooks/Financial Inclusion dataset/Train (1).csv'

# %%
trdata = pd.read_csv(url)

# %%
trdata
# Out:
#       country  year       uniqueid bank_account location_type  \
# 0       Kenya  2018     uniqueid_1          Yes         Rural
# 1       Kenya  2018     uniqueid_2           No         Rural
# 2       Kenya  2018     uniqueid_3          Yes         Urban
# 3       Kenya  2018     uniqueid_4           No         Rural
# 4       Kenya  2018     uniqueid_5           No         Urban
# ...       ...   ...            ...          ...           ...
# 23519  Uganda  2018  uniqueid_2113           No         Rural
# 23520  Uganda  2018  uniqueid_2114           No         Rural
# 23521  Uganda  2018  uniqueid_2115           No         Rural
# 23522  Uganda  2018  uniqueid_2116           No         Urban
# 23523  Uganda  2018  uniqueid_2117           No         Rural
#
#       cellphone_access  household_size  age_of_respondent  \
# 0                  Yes               3                 24
# 1                   No               5                 70
# ...

# %%
trdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  object
#  4   location_type           23524 non-null  object
#  5   cellphone_access        23524 non-null  object
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  object
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 2.3+ MB

# %%
trdata.isnull().sum()
# Out:
# country                   0
# year                      0
# uniqueid                  0
# bank_account              0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %%
trdata.head()
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
trdata2 = trdata.copy()

# %%
trdata2.bank_account.value_counts()
# Out:
# No     20212
# Yes     3312
# Name: bank_account, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
len1 = LabelEncoder()
len2 = LabelEncoder()
len3 = LabelEncoder()
len4 = LabelEncoder()
len5 = LabelEncoder()
len6 = LabelEncoder()
len7 = LabelEncoder()
len8 = LabelEncoder()
len9 = LabelEncoder()

trdata['country'] = len1.fit_transform(trdata['country'])
trdata['bank_account'] = len2.fit_transform(trdata['bank_account'])
trdata['location_type'] = len3.fit_transform(trdata['location_type'])
trdata['cellphone_access'] = len4.fit_transform(trdata['cellphone_access'])
trdata['gender_of_respondent'] = len5.fit_transform(trdata['gender_of_respondent'])
trdata['marital_status'] = len6.fit_transform(trdata['marital_status'])
trdata['relationship_with_head'] = len7.fit_transform(trdata['relationship_with_head'])
trdata['education_level'] = len8.fit_transform(trdata['education_level'])
trdata['job_type'] = len9.fit_transform(trdata['job_type'])

# %%
print(len1.classes_)
print(len2.classes_)
print(len3.classes_)
print(len4.classes_)
print(len5.classes_)
print(len6.classes_)
print(len7.classes_)
print(len8.classes_)
print(len9.classes_)
# Out:
# ['Kenya' 'Rwanda' 'Tanzania' 'Uganda']
# ['No' 'Yes']
# ['Rural' 'Urban']
# ['No' 'Yes']
# ['Female' 'Male']
# ['Divorced/Seperated' 'Dont know' 'Married/Living together'
#  'Single/Never Married' 'Widowed']
# ['Child' 'Head of Household' 'Other non-relatives' 'Other relative'
#  'Parent' 'Spouse']
# ['No formal education' 'Other/Dont know/RTA' 'Primary education'
#  'Secondary education' 'Tertiary education'
#  'Vocational/Specialised training']
# ['Dont Know/Refuse to answer' 'Farming and Fishing'
#  'Formally employed Government' 'Formally employed Private'
#  'Government Dependent' 'Informally employed' 'No Income' 'Other Income'
#  'Remittance Dependent' 'Self employed']

# %%
trdata.drop(columns = 'uniqueid', axis = 1, inplace = True)

# %%
corr_matrix=trdata.corr()
corr_matrix["bank_account"].sort_values(ascending=False)
# Out:
# bank_account              1.000000
# education_level           0.323768
# cellphone_access          0.209669
# gender_of_respondent      0.117234
# year                      0.112318
# location_type             0.087288
# age_of_respondent         0.019429
# household_size           -0.028326
# marital_status           -0.038739
# job_type                 -0.064171
# relationship_with_head   -0.070853
# country                  -0.161362
# Name: bank_account, dtype: float64

# %%
plt.figure(figsize = (10,6))
dataplot = sns.heatmap(trdata.corr(), annot=True)
plt.show()

# %%
gender_count = trdata2['gender_of_respondent'].value_counts()
# Create pie chart
fig, ax = plt.subplots()
ax.pie(gender_count, labels=gender_count.index, autopct='%1.1f%%')
ax.set_title('Gender Distribution')
plt.show()

# %%
age_groups = [0, 18, 25, 35, 45, 55, 65, 100]
labels = ['0-17', '18-24', '25-34', '35-44', '45-54', '55-64', '65+']
# Create age groups based on the age column
trdata2['age_groups'] = pd.cut(trdata2['age_of_respondent'], bins=age_groups, labels=labels)
# Create a histogram of age groups
fig, ax = plt.subplots(figsize=(8, 6))
trdata2['age_groups'].value_counts().sort_index().plot(kind='bar', color='purple', ax=ax)
ax.set_xlabel('Age Group')
ax.set_ylabel('Count')
ax.set_title('Customer Age Group Distribution')
# Add labels to histogram bars
for i in ax.containers:
  ax.bar_label(i)

plt.show()

# %%
trdata2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  object
#  4   location_type           23524 non-null  object
#  5   cellphone_access        23524 non-null  object
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  object
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
#  13  age_groups              23524 non-null  category
# ...

# %%
sns.countplot(data = trdata2, x = 'age_groups', hue = 'bank_account')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data = trdata2, x = 'cellphone_access', hue = 'bank_account')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
trdata2.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'bank_account', 'location_type',
#        'cellphone_access', 'household_size', 'age_of_respondent',
#        'gender_of_respondent', 'relationship_with_head', 'marital_status',
#        'education_level', 'job_type', 'age_groups'],
#       dtype='object')

# %%
sns.countplot(data = trdata2, x = 'country', hue = 'bank_account')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.catplot(x="bank_account", kind="count", data=trdata2, col="year")
sns.despine()
plt.show()

# %%
sns.countplot(data = trdata2, x = 'location_type', hue = 'bank_account')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pd.crosstab(trdata2["bank_account"],trdata2["location_type"])
# Out:
# location_type  Rural  Urban
# bank_account
# No             12672   7540
# Yes             1671   1641

# %%
trdata2.gender_of_respondent.value_counts()
# Out:
# Female    13877
# Male       9647
# Name: gender_of_respondent, dtype: int64

# %%
pd.crosstab(trdata2["bank_account"],trdata2["gender_of_respondent"])
# Out:
# gender_of_respondent  Female  Male
# bank_account
# No                     12395  7817
# Yes                     1482  1830

# %%
sns.countplot(data = trdata2, x = 'gender_of_respondent', hue = 'bank_account')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data = trdata2, y = 'relationship_with_head', hue = 'bank_account')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data = trdata2, y = 'marital_status', hue = 'bank_account')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data = trdata2, y = 'education_level', hue = 'bank_account')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data = trdata2, y = 'job_type', hue = 'bank_account')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# MACHINE LEARNING
